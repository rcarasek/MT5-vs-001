# %%
import pandas as pd

# %%
# CONFIGURANDO YAHOO FINANCE
# !pip install yfinance --upgrade --no-cache-dir
import yfinance as yf

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
ativos = "BOVA11.SA BBAS3.SA BBSE3.sa B3SA3.SA"
dados_ativos = yf.download(tickers=ativos, period='1y')['Adj Close']
#ibov = yf.download('BOVA11.SA', period='1y')["Adj Close"]
#ibov = ibov / ibov.iloc[0]
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
retorno_ativos = dados_ativos.pct_change()
retorno_ativos.head(3)
# Out:
#             B3SA3.SA  BBAS3.SA  BBSE3.SA  BOVA11.SA
# Date
# 2020-06-18       NaN       NaN       NaN        NaN
# 2020-06-19  0.012708 -0.013372  0.034867   0.000108
# 2020-06-22 -0.013137 -0.020625  0.001389  -0.009607

# %%
retorno_ativos_acumulado = (1 + retorno_ativos).cumprod()   # numpy.cumprod() function is used when we want to compute the cumulative product of array elements over a given axis.
retorno_ativos_acumulado.iloc[0] = 1
retorno_ativos_acumulado.head()
# Out:
#             B3SA3.SA  BBAS3.SA  BBSE3.SA  BOVA11.SA
# Date
# 2020-06-18  1.000000  1.000000  1.000000   1.000000
# 2020-06-19  1.012708  0.986628  1.034867   1.000108
# 2020-06-22  0.999404  0.966279  1.036305   0.990500
# 2020-06-23  1.038125  0.974709  1.033429   0.996006
# 2020-06-24  1.045473  0.936628  1.019770   0.979920

# %%
retorno_ativos_acumulado.plot(figsize=(18,8))
# Out:
# <AxesSubplot:xlabel='Date'>
